# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ptl

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-47648c43-6c3d-46d2-bc09-1d1afc145965" name="files[]" multiple disabled />
#      <output id="result-47648c43-6c3d-46d2-bc09-1d1afc145965">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset_crime_boston.xlsx to dataset_crime_boston.xlsx
# User uploaded file "dataset_crime_boston.xlsx" with length 615157 bytes

# %%
data = pd.read_excel('dataset_crime_boston.xlsx')

# %%
data.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
weekCrimeDay = data['DAY_OF_WEEK'].value_counts()
weekCrimeDay
# Out:
# Friday       860
# Thursday     844
# Wednesday    807
# Saturday     794
# Sunday       741
# Monday       734
# Tuesday      595
# Name: DAY_OF_WEEK, dtype: int64

# %%
weekCrimeDay.plot.bar()

# %%
crimeLocation = data.loc[:'OFFENSE_CODE','DISTRICT'].fillna("No location added").value_counts()
crimeLocation
# Out:
# B2                   788
# C11                  665
# D4                   643
# B3                   629
# A1                   602
# C6                   485
# D14                  367
# E18                  319
# E13                  257
# E5                   241
# A7                   177
# No location added    111
# A15                   91
# Name: DISTRICT, dtype: int64

# %%
crimeLocation.plot.bar()

# %%
data.DISTRICT.loc[data.YEAR ==2015].value_counts().plot.bar() 
plt.show()
data.DISTRICT.loc[data.YEAR ==2016].value_counts().plot.bar() 
plt.show()
data.DISTRICT.loc[data.YEAR ==2017].value_counts().plot.bar() 
plt.show()
data.DISTRICT.loc[data.YEAR ==2018].value_counts().plot.bar() 
plt.show()

# %%
crimeKind = data.OFFENSE_CODE_GROUP.value_counts()

# %%
crimeKind
# Out:
# Motor Vehicle Accident Response     673
# Larceny                             473
# Investigate Person                  412
# Medical Assistance                  408
# Other                               290
# Verbal Disputes                     275
# Simple Assault                      259
# Vandalism                           259
# Towed                               246
# Property Lost                       215
# Drug Violation                      203
# Investigate Property                200
# Larceny From Motor Vehicle          196
# Aggravated Assault                  114
# Fraud                               101
# Warrant Arrests                      88
# Property Found                       85
# Auto Theft                           82
# Violations                           71
# Harassment                           69
# Residential Burglary                 66
# Robbery                              60
# Disorderly Conduct                   43
# ...

# %%
crimeKind.plot.bar()
